# %%
import pandas as pd
from os import path
pd.set_option('display.max_colwidth', None)
import csv
import os
import matplotlib.pyplot as plt

# %%
cd EPIC_flowsheets_cleaned_filtered
# Out:
# [Errno 2] No such file or directory: 'EPIC_flowsheets_cleaned_filtered'
# /home/groups/barbarae/priyanka/mover_pressors

# %%
ls
# Out:
# clean_flowsheets.sh      filter_patient_meds.py  patient_measurments.ipynb
# filter_patient_meds.err  filter_patient_meds.sh  pressor_map_mapping.ipynb
# filter_patient_meds.out  flowsheets.ipynb        README.md

# %% [markdown]
# ### Combine all flowsheets and save

# %%
dfs = []

# %%
# Iterate over each CSV file in the input directory
for file_name in os.listdir('./'):
    if file_name.endswith('.csv'):
        # Full path to the CSV file
        file_path = os.path.join('./', file_name)
        print(f"Processing {file_path}")
        
        # Read the CSV file into a DataFrame
        df = pd.read_csv(file_path)
        
        # Append the DataFrame to the list
        dfs.append(df)
# Out:
# Processing ./flowsheet_part1.csv
# Processing ./flowsheet_part13.csv
# Processing ./flowsheet_part8.csv
# Processing ./flowsheet_part7.csv
# Processing ./flowsheet_part9.csv
# Processing ./flowsheet_part14.csv

# %%
combined_df = pd.concat(dfs, ignore_index=True)

# %%
combined_df
# Out:
#          Unnamed: 0            LOG_ID               MRN  \
# 0                 5  d586108388315523  4c482e1b3ab4127a
# 1                69  e01cb2c5f9ca0f83  f0fc2f475e6141f7
# 2                91  f3ad6778179e0ae1  56e93c2f2c1e9351
# 3               126  f3ad6778179e0ae1  56e93c2f2c1e9351
# 4               136  0e343e3fb908dc39  2b0c1b8c911861b9
# ...             ...               ...               ...
# 8900769    56958821  fa9ba3b7668ebe1e  0572634629befc15
# 8900770    56958822  1c97a64ebc54b19e  0572634629befc15
# 8900771    56958825  fa9ba3b7668ebe1e  0572634629befc15
# 8900772    56958910  65cca8b449c639cf  33a8e61d26d56d92
# 8900773    56958911  65cca8b449c639cf  33a8e61d26d56d92
#
#                               FLO_NAME FLO_DISPLAY_NAME RECORD_TYPE  \
# 0                         Vital Signs        MAP (mmHg)     POST-OP
# 1                         Vital Signs        MAP (mmHg)     POST-OP
# 2                         Vital Signs        MAP (mmHg)     POST-OP
# 3                         Vital Signs        MAP (mmHg)     POST-OP
# 4                         Vital Signs        MAP (mmHg)     POST-OP
# ...                                ...              ...         ...
# 8900769  Dialysis Vitals and Treatment       MAP (mmHg)     POST-OP
# 8900770  Dialysis Vitals and Treatment       MAP (mmHg)     POST-OP
# 8900771  Dialysis Vitals and Treatment       MAP (mmHg)     POST-OP
# 8900772                   Vital Signs        MAP (mmHg)     POST-OP
# 8900773                   Vital Signs        MAP (mmHg)     POST-OP
#
#                RECORDED_TIME  MEAS_VALUE  UNITS
# 0        2019-10-18 00:00:00        77.0    NaN
# 1        2019-02-12 00:00:00        83.0    NaN
# 2        2019-04-04 00:00:00        77.0    NaN
# 3        2019-04-04 00:00:00        77.0    NaN
# 4        2018-12-01 00:00:00       116.0    NaN
# ...                      ...         ...    ...
# 8900769  2022-06-29 08:34:00        70.0    NaN
# 8900770  2022-06-29 08:34:00        70.0    NaN
# 8900771  2022-06-29 08:34:00        70.0    NaN
# 8900772  2022-02-23 00:14:00        83.0    NaN
# 8900773  2022-02-23 00:14:00        83.0    NaN
#
# [8900774 rows x 9 columns]

# %%
df_cleaned = combined_df.dropna(subset=['MEAS_VALUE'])
#df_cleaned = df_cleaned.drop(df_cleaned['UNITS'])

# %%
df_cleaned
# Out:
#          Unnamed: 0            LOG_ID               MRN  \
# 0                 5  d586108388315523  4c482e1b3ab4127a
# 1                69  e01cb2c5f9ca0f83  f0fc2f475e6141f7
# 2                91  f3ad6778179e0ae1  56e93c2f2c1e9351
# 3               126  f3ad6778179e0ae1  56e93c2f2c1e9351
# 4               136  0e343e3fb908dc39  2b0c1b8c911861b9
# ...             ...               ...               ...
# 8900769    56958821  fa9ba3b7668ebe1e  0572634629befc15
# 8900770    56958822  1c97a64ebc54b19e  0572634629befc15
# 8900771    56958825  fa9ba3b7668ebe1e  0572634629befc15
# 8900772    56958910  65cca8b449c639cf  33a8e61d26d56d92
# 8900773    56958911  65cca8b449c639cf  33a8e61d26d56d92
#
#                               FLO_NAME FLO_DISPLAY_NAME RECORD_TYPE  \
# 0                         Vital Signs        MAP (mmHg)     POST-OP
# 1                         Vital Signs        MAP (mmHg)     POST-OP
# 2                         Vital Signs        MAP (mmHg)     POST-OP
# 3                         Vital Signs        MAP (mmHg)     POST-OP
# 4                         Vital Signs        MAP (mmHg)     POST-OP
# ...                                ...              ...         ...
# 8900769  Dialysis Vitals and Treatment       MAP (mmHg)     POST-OP
# 8900770  Dialysis Vitals and Treatment       MAP (mmHg)     POST-OP
# 8900771  Dialysis Vitals and Treatment       MAP (mmHg)     POST-OP
# 8900772                   Vital Signs        MAP (mmHg)     POST-OP
# 8900773                   Vital Signs        MAP (mmHg)     POST-OP
#
#                RECORDED_TIME  MEAS_VALUE  UNITS
# 0        2019-10-18 00:00:00        77.0    NaN
# 1        2019-02-12 00:00:00        83.0    NaN
# 2        2019-04-04 00:00:00        77.0    NaN
# 3        2019-04-04 00:00:00        77.0    NaN
# 4        2018-12-01 00:00:00       116.0    NaN
# ...                      ...         ...    ...
# 8900769  2022-06-29 08:34:00        70.0    NaN
# 8900770  2022-06-29 08:34:00        70.0    NaN
# 8900771  2022-06-29 08:34:00        70.0    NaN
# 8900772  2022-02-23 00:14:00        83.0    NaN
# 8900773  2022-02-23 00:14:00        83.0    NaN
#
# [8884459 rows x 9 columns]

# %%
output_file = 'MAP.csv'
df_cleaned.to_csv(output_file, index=False)

# %% [markdown]
# ### Analysis

# %%
df = pd.read_csv('MAP.csv', index_col=0)

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#                       LOG_ID               MRN                       FLO_NAME  \
# Unnamed: 0
# 5           d586108388315523  4c482e1b3ab4127a                   Vital Signs
# 69          e01cb2c5f9ca0f83  f0fc2f475e6141f7                   Vital Signs
# 91          f3ad6778179e0ae1  56e93c2f2c1e9351                   Vital Signs
# 136         0e343e3fb908dc39  2b0c1b8c911861b9                   Vital Signs
# 157         d4daafc3a6802ca0  4d0311a2de662c9e                   Vital Signs
# ...                      ...               ...                            ...
# 56958717    fa9ba3b7668ebe1e  0572634629befc15  Dialysis Vitals and Treatment
# 56958785    1c97a64ebc54b19e  0572634629befc15  Dialysis Vitals and Treatment
# 56958789    fa9ba3b7668ebe1e  0572634629befc15  Dialysis Vitals and Treatment
# 56958817    1c97a64ebc54b19e  0572634629befc15  Dialysis Vitals and Treatment
# 56958821    fa9ba3b7668ebe1e  0572634629befc15  Dialysis Vitals and Treatment
#
#            FLO_DISPLAY_NAME RECORD_TYPE        RECORDED_TIME  MEAS_VALUE  \
# Unnamed: 0
# 5                MAP (mmHg)     POST-OP  2019-10-18 00:00:00        77.0
# 69               MAP (mmHg)     POST-OP  2019-02-12 00:00:00        83.0
# 91               MAP (mmHg)     POST-OP  2019-04-04 00:00:00        77.0
# 136              MAP (mmHg)     POST-OP  2018-12-01 00:00:00       116.0
# 157              MAP (mmHg)     POST-OP  2019-08-14 00:00:00        83.0
# ...                     ...         ...                  ...         ...
# 56958717         MAP (mmHg)     POST-OP  2022-06-29 08:45:00        69.0
# 56958785         MAP (mmHg)     POST-OP  2022-06-29 08:30:00        79.0
# 56958789         MAP (mmHg)     POST-OP  2022-06-29 08:30:00        79.0
# 56958817         MAP (mmHg)     POST-OP  2022-06-29 08:34:00        70.0
# 56958821         MAP (mmHg)     POST-OP  2022-06-29 08:34:00        70.0
#
#             UNITS
# Unnamed: 0
# 5             NaN
# 69            NaN
# 91            NaN
# 136           NaN
# 157           NaN
# ...           ...
# 56958717      NaN
# 56958785      NaN
# 56958789      NaN
# 56958817      NaN
# 56958821      NaN
#
# [1559441 rows x 8 columns]

# %%
df = df.drop_duplicates()

# %%
df['RECORDED_TIME'].nunique()
# Out:
# 353628

# %%
df['LOG_ID'].nunique()
# Out:
# 30172

# %%
df['MRN'].nunique()
# Out:
# 20073

# %%
df_patient = df[df['MRN'] == '4c482e1b3ab4127a']

# %%
df_patient['LOG_ID'].nunique()
# Out:
# 4

# %%
df_patient['LOG_ID'].unique()
# Out:
# array(['d586108388315523', '41c689c44078aab6', 'cf7ac282352364cd',
#        'f101063f08eb3a3e'], dtype=object)

# %%
df_patient_visit = df_patient[df_patient['LOG_ID'] == 'd586108388315523']

# %%
df_patient_visit
# Out:
#                       LOG_ID               MRN      FLO_NAME FLO_DISPLAY_NAME  \
# Unnamed: 0
# 5           d586108388315523  4c482e1b3ab4127a  Vital Signs        MAP (mmHg)
# 68826       d586108388315523  4c482e1b3ab4127a  Vital Signs        MAP (mmHg)
# 114752      d586108388315523  4c482e1b3ab4127a  Vital Signs        MAP (mmHg)
# 151552      d586108388315523  4c482e1b3ab4127a  Vital Signs        MAP (mmHg)
# 181908      d586108388315523  4c482e1b3ab4127a  Vital Signs        MAP (mmHg)
# ...                      ...               ...           ...              ...
# 27086244    d586108388315523  4c482e1b3ab4127a  Vital Signs        MAP (mmHg)
# 27206913    d586108388315523  4c482e1b3ab4127a  Vital Signs        MAP (mmHg)
# 27385071    d586108388315523  4c482e1b3ab4127a  Vital Signs        MAP (mmHg)
# 27463871    d586108388315523  4c482e1b3ab4127a  Vital Signs        MAP (mmHg)
# 27719293    d586108388315523  4c482e1b3ab4127a  Vital Signs        MAP (mmHg)
#
#            RECORD_TYPE        RECORDED_TIME  MEAS_VALUE  UNITS
# Unnamed: 0
# 5              POST-OP  2019-10-18 00:00:00        77.0    NaN
# 68826          POST-OP  2019-10-18 01:00:00        82.0    NaN
# 114752         POST-OP  2019-10-18 02:00:00        94.0    NaN
# 151552         POST-OP  2019-10-18 03:00:00       106.0    NaN
# 181908         POST-OP  2019-10-18 04:00:00       118.0    NaN
# ...                ...                  ...         ...    ...
# 27086244       POST-OP  2019-11-13 20:03:00        82.0    NaN
# 27206913       POST-OP  2019-11-13 23:25:00        75.0    NaN
# 27385071       POST-OP  2019-11-14 04:26:00        98.0    NaN
# 27463871       POST-OP  2019-11-14 07:30:00        89.0    NaN
# 27719293       POST-OP  2019-11-14 12:22:00        70.0    NaN
#
# [604 rows x 8 columns]

# %%
df_patient_visit['RECORDED_TIME'].nunique()
# Out:
# 604

# %%
patient_id = '4c482e1b3ab4127a'
log_id = 'd586108388315523'

# %%
#plt.scatter(x=df_patient_visit['RECORDED_TIME'], y=df_patient_visit['MEAS_VALUE'], s=0.1)
fig, ax = plt.subplots(figsize=(10, 5))
plt.xlabel('Time')
plt.ylabel('MAP')
plt.title(f'MRN: {patient_id}, LOG_ID: {log_id} MAP Over Time')
plt.plot(df_patient_visit['MEAS_VALUE'], marker='o', linestyle='-', markersize=2)

# %%
import torch
import pandas as pd
import tarfile
import os
import matplotlib.pyplot as plt

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
    print("CUDA is available. Using GPU.")
else:
    device = torch.device('cpu')
    print("CUDA is not available. Using CPU.")
# Out:
# CUDA is available. Using GPU.

# %%
patient_information = pd.read_csv('EPIC_EMR/EMR/patient_information.csv')
patient_information = patient_information.drop_duplicates()
hours_df = pd.read_csv('hours_fb_df_new.csv', index_col=0)

# %%
def agg_func(series):
    if series.nunique() == 1:
        return series.iloc[0]
    else:
        return '|'.join(map(str, series.unique()))

# %%
patient_information['HOSP_ADMSN_TIME'] = pd.to_datetime(patient_information['HOSP_ADMSN_TIME'])
patient_information['HOSP_DISCH_TIME'] = pd.to_datetime(patient_information['HOSP_DISCH_TIME'])
hours_df['HOSP_ADMSN_TIME'] = pd.to_datetime(hours_df['HOSP_ADMSN_TIME'])
hours_df['HOSP_DISCH_TIME'] = pd.to_datetime(hours_df['HOSP_DISCH_TIME'])
# Out:
# /tmp/ipykernel_129265/3590612282.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   patient_information['HOSP_ADMSN_TIME'] = pd.to_datetime(patient_information['HOSP_ADMSN_TIME'])
# /tmp/ipykernel_129265/3590612282.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   patient_information['HOSP_DISCH_TIME'] = pd.to_datetime(patient_information['HOSP_DISCH_TIME'])

# %%
patient_information.columns
# Out:
# Index(['LOG_ID', 'MRN', 'DISCH_DISP_C', 'DISCH_DISP', 'HOSP_ADMSN_TIME',
#        'HOSP_DISCH_TIME', 'LOS', 'ICU_ADMIN_FLAG', 'SURGERY_DATE',
#        'BIRTH_DATE', 'HEIGHT', 'WEIGHT', 'SEX', 'PRIMARY_ANES_TYPE_NM',
#        'ASA_RATING_C', 'ASA_RATING', 'PATIENT_CLASS_GROUP', 'PATIENT_CLASS_NM',
#        'PRIMARY_PROCEDURE_NM', 'IN_OR_DTTM', 'OUT_OR_DTTM',
#        'AN_START_DATETIME', 'AN_STOP_DATETIME'],
#       dtype='object')

# %%
# Merge demographic data
cols = ['MRN', 'LOG_ID', 'ICU_ADMIN_FLAG', 'SURGERY_DATE', 'DISCH_DISP_C', 'DISCH_DISP', 'BIRTH_DATE', 'SEX', 'PRIMARY_PROCEDURE_NM', 'HOSP_ADMSN_TIME', 'HOSP_DISCH_TIME', 'ASA_RATING_C', 'ASA_RATING']
final_df = pd.merge(hours_df, patient_information[cols], on=['MRN', 'HOSP_ADMSN_TIME', 'HOSP_DISCH_TIME'], how='inner')
final_df
# Out:
#                    MRN     HOSP_ADMSN_TIME     HOSP_DISCH_TIME  HOURS  \
# 0     38f2abdfacbed586 2021-08-24 07:19:00 2021-09-06 14:56:00    0.0
# 1     38f2abdfacbed586 2021-08-24 07:19:00 2021-09-06 14:56:00    0.0
# 2     38f2abdfacbed586 2021-08-24 07:19:00 2021-09-06 14:56:00    0.0
# 3     2d604e5cc7818233 2022-08-08 22:20:00 2022-08-23 15:28:00    0.0
# 4     3b7fd5bd48dae180 2022-01-20 01:47:00 2022-01-31 15:39:00    0.0
# ...                ...                 ...                 ...    ...
# 6015  5800610092b18862 2020-01-31 19:26:00 2020-03-10 11:25:00    0.0
# 6016  5800610092b18862 2020-01-31 19:26:00 2020-03-10 11:25:00    0.0
# 6017  5800610092b18862 2020-01-31 19:26:00 2020-03-10 11:25:00    0.0
# 6018  5800610092b18862 2020-01-31 19:26:00 2020-03-10 11:25:00    0.0
# 6019  3e56b462de0132a4 2021-03-05 08:42:00 2021-04-04 21:17:00    0.0
#
#                 LOG_ID ICU_ADMIN_FLAG  SURGERY_DATE  DISCH_DISP_C  \
# 0     2e9484ebef54f1b2            Yes  8/24/21 0:00           6.0
# 1     ce4f955d458acfdd            Yes  8/26/21 0:00           6.0
# 2     f84a2bf4925a9b13            Yes   9/2/21 0:00           6.0
# 3     e9fa1fab0d8922fb            Yes   8/9/22 0:00          20.0
# 4     8dc848e496b34760            Yes  1/26/22 0:00          20.0
# ...                ...            ...           ...           ...
# 6015  5b2468b0f5162c9f            Yes  2/21/20 0:00          16.0
# 6016  c50dc1b7e703bfd8            Yes  2/27/20 0:00          16.0
# 6017  8109c254e2c57519            Yes  2/28/20 0:00          16.0
# 6018  bf0be14ec26f19d3            Yes   3/4/20 0:00          16.0
# 6019  cdbeecb4fbc85464            Yes  3/20/21 0:00          26.0
#
#                                    DISCH_DISP  BIRTH_DATE     SEX  \
# 0                    Skilled Nursing Facility          82    Male
# 1                    Skilled Nursing Facility          82    Male
# 2                    Skilled Nursing Facility          82    Male
# 3            Home Healthcare IP Admit Related          42    Male
# 4            Home Healthcare IP Admit Related          66    Male
# ...                                       ...         ...     ...
# 6015                         Hospice Facility          61    Male
# 6016                         Hospice Facility          61    Male
# 6017                         Hospice Facility          61    Male
# 6018                         Hospice Facility          61    Male
# 6019  Acute Care Facility (not this hospital)          33  Female
#
#                   PRIMARY_PROCEDURE_NM  ASA_RATING_C               ASA_RATING
# 0       IR INSERT CHOLECYSTOSTOMY TUBE           NaN                      NaN
# 1       IR INSERT CHOLECYSTOSTOMY TUBE           NaN                      NaN
# 2                     EGD, WITH BIOPSY           3.0  Severe Systemic Disease
# 3                          CRANIECTOMY           3.0  Severe Systemic Disease
# 4            REPLACEMENT, MITRAL VALVE           4.0   Incapacitating Disease
# ...                                ...           ...                      ...
# 6015                     THORACENTESIS           NaN                      NaN
# 6016  EGD (ESOPHAGOGASTRODUODENOSCOPY)           NaN                      NaN
# 6017  EGD (ESOPHAGOGASTRODUODENOSCOPY)           4.0   Incapacitating Disease
# 6018  EGD (ESOPHAGOGASTRODUODENOSCOPY)           3.0  Severe Systemic Disease
# 6019  NEPHRECTOMY, TRANSPLANTED KIDNEY           4.0   Incapacitating Disease
#
# [6020 rows x 14 columns]

# %%
# Merge diagnoses and post-op complications
post_op_complications = pd.read_csv('EPIC_EMR/EMR/patient_post_op_complications.csv')
patient_visit = pd.read_csv('EPIC_EMR/EMR/patient_visit.csv')
patient_visit = patient_visit.drop_duplicates()
patient_visit.rename(columns={'mrn': 'MRN'}, inplace=True)
diagnosis_and_complications = pd.merge(patient_visit[['LOG_ID', 'MRN', 'diagnosis_code', 'dx_name']],
                                       post_op_complications[['LOG_ID', 'MRN', 'Element_abbr']],
                                       on=['LOG_ID', 'MRN'],
                                       how='inner')
diagnosis_and_complications = diagnosis_and_complications.drop_duplicates()
diagnosis_and_complications_final = diagnosis_and_complications.groupby(['MRN', 'LOG_ID']).agg(agg_func).reset_index()
diagnosis_and_complications_final
# Out:
#                     MRN            LOG_ID                 diagnosis_code  \
# 0      0000c7ccaa009343  47fbfb9938d6067b                          592.0
# 1      0000c7ccaa009343  bd16a67880da1e77                         789.00
# 2      0000e45237d1fc96  611e9c50425dbf55                            nan
# 3      000181ce0ebf1e12  be9a505e236e5b67                            193
# 4      00018b4d9acb258b  189a1d9df810fe26  307.9|nan|786.05|786.09|790.4
# ...                 ...               ...                            ...
# 46248  fff634f64e07b66a  98183e21fcda44c9                          585.6
# 46249  fffb5d2e00cf670f  ca86eca1473b99bf                            nan
# 46250  fffc39a39b57eee7  f18c7d34c4192c9b                            nan
# 46251  fffcb59d973c7e4c  c293e9fef7b0f159                         427.89
# 46252  fffdbbf506ab0725  bf578930b63876ee                          239.4
#
#                                                  dx_name  \
# 0                           Nephrolithiasis|Kidney stone
# 1                                        Left flank pain
# 2      Gunshot wound of right lower extremity, initia...
# 3                  Papillary thyroid carcinoma (CMS-HCC)
# 4      Agitation|Impaired functional mobility, balanc...
# ...                                                  ...
# 46248  ESRD (end stage renal disease) on dialysis (CM...
# 46249     Ruptured globe of right eye, initial encounter
# 46250  Pseudoaneurysm of AV hemodialysis fistula, ini...
# 46251       SVT (supraventricular tachycardia) (CMS-HCC)
# 46252                                      Bladder tumor
#
#                    Element_abbr
# 0      AN Post-op Complications
# 1      AN Post-op Complications
# 2      AN Post-op Complications
# 3      AN Post-op Complications
# 4      AN Post-op Complications
# ...                         ...
# 46248  AN Post-op Complications
# 46249  AN Post-op Complications
# 46250  AN Post-op Complications
# 46251  AN Post-op Complications
# 46252  AN Post-op Complications
#
# [46253 rows x 5 columns]

# %%
# Merge all data
final_df_merged = pd.merge(final_df, diagnosis_and_complications_final, on=['LOG_ID', 'MRN'], how='inner')
final_df_merged
# Out:
#                    MRN     HOSP_ADMSN_TIME     HOSP_DISCH_TIME     HOURS  \
# 0     38f2abdfacbed586 2021-08-24 07:19:00 2021-09-06 14:56:00  0.000000
# 1     2d604e5cc7818233 2022-08-08 22:20:00 2022-08-23 15:28:00  0.000000
# 2     3b7fd5bd48dae180 2022-01-20 01:47:00 2022-01-31 15:39:00  0.000000
# 3     0ea0ab0b01b01c4c 2019-01-12 18:19:00 2019-02-07 18:14:00  0.000000
# 4     bba97a9988e7a2aa 2019-03-24 04:07:00 2019-06-22 18:50:00  0.000000
# ...                ...                 ...                 ...       ...
# 2175  bb2936abd9e070d7 2021-10-21 15:06:00 2021-10-26 00:59:00  0.037777
# 2176  224c476538275696 2022-06-04 22:17:00 2022-07-17 21:59:00  0.000000
# 2177  5800610092b18862 2019-09-22 07:41:00 2019-11-24 17:05:00  0.540456
# 2178  5800610092b18862 2020-01-31 19:26:00 2020-03-10 11:25:00  0.000000
# 2179  3e56b462de0132a4 2021-03-05 08:42:00 2021-04-04 21:17:00  0.000000
#
#                 LOG_ID ICU_ADMIN_FLAG   SURGERY_DATE  DISCH_DISP_C  \
# 0     f84a2bf4925a9b13            Yes    9/2/21 0:00           6.0
# 1     e9fa1fab0d8922fb            Yes    8/9/22 0:00          20.0
# 2     8dc848e496b34760            Yes   1/26/22 0:00          20.0
# 3     8dd494b84151815e            Yes   1/13/19 0:00           6.0
# 4     757c2bee63380c85            Yes    4/2/19 0:00          26.0
# ...                ...            ...            ...           ...
# 2175  c2f69611af88a940            Yes  10/21/21 0:00          16.0
# 2176  90eafc136cb54259            Yes    6/7/22 0:00         107.0
# 2177  a3afe6ae9e8d71d9            Yes  11/10/19 0:00          30.0
# 2178  bf0be14ec26f19d3            Yes    3/4/20 0:00          16.0
# 2179  cdbeecb4fbc85464            Yes   3/20/21 0:00          26.0
#
#                                    DISCH_DISP  BIRTH_DATE     SEX  \
# 0                    Skilled Nursing Facility          82    Male
# 1            Home Healthcare IP Admit Related          42    Male
# 2            Home Healthcare IP Admit Related          66    Male
# 3                    Skilled Nursing Facility          51    Male
# 4     Acute Care Facility (not this hospital)          43  Female
# ...                                       ...         ...     ...
# 2175                         Hospice Facility          53    Male
# 2176                  Sub-Acute Care Facility          45  Female
# 2177                  Long Term Care Facility          60    Male
# 2178                         Hospice Facility          61    Male
# 2179  Acute Care Facility (not this hospital)          33  Female
#
#                                    PRIMARY_PROCEDURE_NM  ASA_RATING_C  \
# 0                                      EGD, WITH BIOPSY           3.0
# 1                                           CRANIECTOMY           3.0
# 2                             REPLACEMENT, MITRAL VALVE           4.0
# 3     CRANIOTOMY, FOR ANEURYSM OR AVM CLIPPING, WITH...           5.0
# 4                                  ORIF ANTERIOR PELVIS           4.0
# ...                                                 ...           ...
# 2175                CRANIECTOMY OR CRANIOTOMY, EMERGENT           4.0
# 2176                              ORIF, FRACTURE, FEMUR           4.0
# 2177                   EGD (ESOPHAGOGASTRODUODENOSCOPY)           3.0
# 2178                   EGD (ESOPHAGOGASTRODUODENOSCOPY)           3.0
# 2179                   NEPHRECTOMY, TRANSPLANTED KIDNEY           4.0
#
#                    ASA_RATING  \
# 0     Severe Systemic Disease
# 1     Severe Systemic Disease
# 2      Incapacitating Disease
# 3                    Moribund
# 4      Incapacitating Disease
# ...                       ...
# 2175   Incapacitating Disease
# 2176   Incapacitating Disease
# 2177  Severe Systemic Disease
# 2178  Severe Systemic Disease
# 2179   Incapacitating Disease
#
#                                          diagnosis_code  \
# 0                                          578.1|785.59
# 1                                      324.9|nan|780.39
# 2                                                 394.0
# 3     431|348.5|429.83|401.9|785.50|432.9|430|nan|79...
# 4                                442.3|854.00|432.1|nan
# ...                                                 ...
# 2175                                        432.0|444.1
# 2176                 828.0|263.0|998.32|959.9|nan|117.9
# 2177         V49.89|V45.89|157.9|250.00|117.9|442.9|nan
# 2178                                    nan|157.1|783.7
# 2179                        427.5|nan|578.1|585.6|401.9
#
#                                                 dx_name  \
# 0                    Melena|Hemorrhagic shock (CMS-HCC)
# 1     Cranial epidural abscess|Nontraumatic subcorti...
# 2                                       Mitral stenosis
# 3     IVH (intraventricular hemorrhage) (CMS-HCC)|Ce...
# 4     Femoral artery pseudo-aneurysm, right (CMS-HCC...
# ...                                                 ...
# 2175  Epidural hematoma|Aortic mural thrombus (CMS-HCC)
# 2176  Multiple extremity fractures|Moderate protein-...
# 2177  On total parenteral nutrition (TPN)|Status pos...
# 2178  Non-intractable vomiting with nausea, unspecif...
# 2179  Cardiac arrest (CMS-HCC)|Type 1 diabetes melli...
#
#                                         Element_abbr
# 0                           AN Post-op Complications
# 1            AN Post-op Complications|Administrative
# 2                           AN Post-op Complications
# 3                           AN Post-op Complications
# 4                           AN Post-op Complications
# ...                                              ...
# 2175                        AN Post-op Complications
# 2176                        AN Post-op Complications
# 2177  AN Post-op Complications|Administrative|Airway
# 2178  Administrative|AN Post-op Complications|Airway
# 2179                        AN Post-op Complications
#
# [2180 rows x 17 columns]

# %%
collapsed_df_final = final_df_merged.groupby(['MRN', 'HOSP_ADMSN_TIME', 'HOSP_DISCH_TIME']).agg(agg_func).reset_index()
collapsed_df_final.to_csv('all_data_final.csv')
collapsed_df_final
# Out:
#                    MRN     HOSP_ADMSN_TIME     HOSP_DISCH_TIME     HOURS  \
# 0     00018b4d9acb258b 2020-07-25 13:33:00 2020-08-25 16:15:00  0.000000
# 1     000db5bb4b440912 2021-10-21 07:53:00 2021-10-28 15:33:00  0.000000
# 2     000f8e3ae0b5aa91 2020-05-27 05:58:00 2020-05-27 16:00:00  0.000000
# 3     001353f9e953c8cd 2020-09-18 09:20:00 2020-09-25 16:29:00  0.000000
# 4     0043f49c66d1a29a 2020-04-12 11:04:00 2020-05-01 15:11:00  0.000000
# ...                ...                 ...                 ...       ...
# 2154  ff6f438387a2f822 2018-11-06 15:54:00 2018-11-22 15:40:00  0.535438
# 2155  ffa83cc8c6472255 2022-06-25 09:44:00 2022-07-28 23:35:00  0.000000
# 2156  ffd4085849ae2443 2019-04-30 16:17:00 2019-05-11 16:44:00  0.000000
# 2157  ffe4b7d7fa95554d 2021-06-10 05:11:00 2021-07-15 20:40:00  0.366460
# 2158  fffc39a39b57eee7 2022-06-09 12:34:00 2022-06-20 16:45:00  0.000000
#
#                 LOG_ID ICU_ADMIN_FLAG   SURGERY_DATE  DISCH_DISP_C  \
# 0     189a1d9df810fe26            Yes    8/3/20 0:00           6.0
# 1     21d28a9add40b0c4            Yes  10/23/21 0:00          20.0
# 2     80afb4c2735257cd            Yes   5/27/20 0:00           3.0
# 3     fc47d3637476c87e            Yes   9/20/20 0:00          15.0
# 4     558d26139a0cdfc0            Yes   4/22/20 0:00          15.0
# ...                ...            ...            ...           ...
# 2154  2158919443f9f462            Yes  11/13/18 0:00          15.0
# 2155  73be2a55e2002335            Yes   6/26/22 0:00          30.0
# 2156  5f6e3e156c0aa0d3            Yes    5/8/19 0:00           6.0
# 2157  e8a53b58e0a341a1            Yes   6/10/21 0:00           3.0
# 2158  f18c7d34c4192c9b            Yes    6/9/22 0:00           6.0
#
#                             DISCH_DISP BIRTH_DATE     SEX  \
# 0             Skilled Nursing Facility         80    Male
# 1     Home Healthcare IP Admit Related         77    Male
# 2                              Expired         36    Male
# 3                         Home Routine         78  Female
# 4                         Home Routine         64    Male
# ...                                ...        ...     ...
# 2154                      Home Routine         60    Male
# 2155           Long Term Care Facility         57    Male
# 2156          Skilled Nursing Facility         63    Male
# 2157                           Expired         85  Female
# 2158          Skilled Nursing Facility         55    Male
#
#                                    PRIMARY_PROCEDURE_NM ASA_RATING_C  \
# 0                                        BIOPSY, MUSCLE          4.0
# 1                   CABG (CORONARY ARTERY BYPASS GRAFT)          4.0
# 2                              LAPAROSCOPY, EXPLORATORY          5.0
# 3                   CABG (CORONARY ARTERY BYPASS GRAFT)          4.0
# 4     HIPEC - CHEMOTHERAPY, INTRAPERITONEAL, HYPERTH...          3.0
# ...                                                 ...          ...
# 2154                          REPLACEMENT, AORTIC VALVE          4.0
# 2155  CRANIOTOMY, FOR ANEURYSM OR AVM CLIPPING, WITH...          3.0
# 2156                            ENDARTERECTOMY, CAROTID          3.0
# 2157                                    HEMIGLOSSECTOMY          3.0
# 2158                  IRRIGATION AND DEBRIDEMENT, WOUND          4.0
#
#                    ASA_RATING  \
# 0      Incapacitating Disease
# 1      Incapacitating Disease
# 2                    Moribund
# 3      Incapacitating Disease
# 4     Severe Systemic Disease
# ...                       ...
# 2154   Incapacitating Disease
# 2155  Severe Systemic Disease
# 2156  Severe Systemic Disease
# 2157  Severe Systemic Disease
# 2158   Incapacitating Disease
#
#                                          diagnosis_code  \
# 0                         307.9|nan|786.05|786.09|790.4
# 1                                                794.39
# 2                                                289.59
# 3                                         794.39|414.00
# 4                                                   nan
# ...                                                 ...
# 2154                                        428.0|428.9
# 2155                                    435.9|437.3|nan
# 2156  437.0|434.91|272.4|433.10|443.9|444.22|790.29|...
# 2157   427.31|nan|511.9|518.81|276.4|141.9|284.19|584.9
# 2158                                                nan
#
#                                                 dx_name  \
# 0     Agitation|Impaired functional mobility, balanc...
# 1                                  Abnormal stress test
# 2                                Closed splenic rupture
# 3          Abnormal stress echo|Coronary artery disease
# 4     Malignant neoplasm of stomach, unspecified loc...
# ...                                                 ...
# 2154  Acute on chronic congestive heart failure (CMS...
# 2155  Cerebral vasospasm|Aneurysm of middle cerebral...
# 2156  Intracranial atherosclerosis|Acute ischemic ri...
# 2157  Paroxysmal atrial fibrillation (CMS-HCC)|Acute...
# 2158  Pseudoaneurysm of AV hemodialysis fistula, ini...
#
#                   Element_abbr
# 0     AN Post-op Complications
# 1     AN Post-op Complications
# 2     AN Post-op Complications
# 3     AN Post-op Complications
# 4     AN Post-op Complications
# ...                        ...
# 2154  AN Post-op Complications
# 2155  AN Post-op Complications
# 2156  AN Post-op Complications
# 2157  AN Post-op Complications
# 2158  AN Post-op Complications
#
# [2159 rows x 17 columns]
